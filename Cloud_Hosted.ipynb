# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nogibjj/Hongyi-Duan-Cloud-Hosted/main/Heroes_3.csv")
df
# Out:
#        Heroes     Skill 1     Skill 2         Race  Hero Score  Race Score
# 0      Kailin      Houqin     Jianshu        Bilei         9.5         8.0
# 1    Kaiserui  Zhaohunshu   Fangyushu       Muyuan        10.0         9.5
# 2     Shakete  Jingongshu     Zhanshu   Dixiacheng         9.5         7.5
# 3       Adela  Waijiaoshu   Zhihuishu     Chengbao         9.5         9.0
# 4        Luna   Zhihuishu   Huoximofa  Yuansucheng         9.5         9.5
# 5   Siqiangke  Zhaohunshu    Dikangli       Muyuan         3.0         9.5
# 6       Taize  Fangyunshu  Fangyunshu       Yaosai         9.0         7.0
# 7  Kenluohage  Jingongshu  Jingongshu       Judian         8.5         6.5

# %%
# Add a column
df['Skill Score'] = np.array([9.5, 9, 9, 8.5, 8, 7, 9, 9])

# Add a row
df.loc[8] = np.array(['Gengna', 'Houqin', 'Zhanshu', 'Bilei', '9,5', '7.5', '9.5'])

# Modify a value
df.loc[0, 'Race Score'] = 8.5

df
# Out:
#        Heroes     Skill 1     Skill 2         Race Hero Score Race Score  \
# 0      Kailin      Houqin     Jianshu        Bilei        9.5        8.5
# 1    Kaiserui  Zhaohunshu   Fangyushu       Muyuan       10.0        9.5
# 2     Shakete  Jingongshu     Zhanshu   Dixiacheng        9.5        7.5
# 3       Adela  Waijiaoshu   Zhihuishu     Chengbao        9.5        9.0
# 4        Luna   Zhihuishu   Huoximofa  Yuansucheng        9.5        9.5
# 5   Siqiangke  Zhaohunshu    Dikangli       Muyuan        3.0        9.5
# 6       Taize  Fangyunshu  Fangyunshu       Yaosai        9.0        7.0
# 7  Kenluohage  Jingongshu  Jingongshu       Judian        8.5        6.5
# 8      Gengna      Houqin     Zhanshu        Bilei        9,5        7.5
#
#   Skill Score
# 0         9.5
# 1         9.0
# 2         9.0
# 3         8.5
# 4         8.0
# 5         7.0
# 6         9.0
# 7         9.0
# 8         9.5
